# %%
import gymnasium as gym
import numpy as np
import random
import tensorflow as tf
from collections import deque
import os
from keras.models import load_model

# %%
env = gym.make("CartPole-v1")
env.reset()
# Out:
# (array([ 0.02941768, -0.00729542, -0.02607945,  0.02411666], dtype=float32),
#  {})

# %%
class agent1():
    def create_model(self):
        neural_n= tf.keras.Sequential([
            tf.keras.layers.Dense(512, input_shape=(4,), activation="relu"),
            tf.keras.layers.Dense(256, activation="relu"),
            tf.keras.layers.Dense(64, activation="relu"),
            tf.keras.layers.Dense(2, activation="linear")
        ])

        neural_n.compile(optimizer="adam", loss="mse", metrics=["accuracy"])

        return neural_n

    def __init__(self):
        self.env = gym.make("CartPole-v1")
        self.main_nn = self.create_model()
        self.discount_rate=0.9
        self.e=1
        self.decay=0.001
        self.eps= 1000
        self.train_start = 1000
        self.batch_size=64
        self.memory = deque(maxlen=2000)


    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if len(self.memory)> self.train_start:
            self.e-=self.decay

    def act(self, state):
        if random.uniform(0,1)< self.e:
            action = env.action_space.sample()
        else:
            action = np.argmax(self.main_nn.predict(state, verbose=0))

        return action
    
    def untuple(self, state):
        if isinstance(state, tuple):
            state=state[0]

        return state
    
    def replay_memory(self):
        if len(self.memory) < self.train_start:
            return
        
        minibatch = random.sample(self.memory, min(len(self.memory), self.batch_size))

        states = np.zeros((len(minibatch), 4))
        next_states = np.zeros((len(minibatch), 4))
        actions, rewards, dones = [], [], []

        for i, (state, action, reward, next_state, done) in enumerate(minibatch):
            states[i] = self.untuple(state)
            next_states[i]= self.untuple(next_state)
            actions.append(int(action))
            rewards.append(reward)
            dones.append(done)

        targets=self.main_nn.predict(states, verbose=0)
        targets_next = self.main_nn.predict(next_states, verbose=0)

        for i in range(self.batch_size):
            if dones[i]:
                targets[i][actions[i]]=rewards[i]
            else:
                targets[i][actions[i]]=rewards[i]+self.discount_rate*np.max(targets_next[i])

        self.main_nn.fit(states, targets, batch_size=self.batch_size, verbose=0)

    def load(self, name):
        self.model = load_model(name)

    def save(self, name):
        self.main_nn.save(name)

    def run(self):
        training=True
        for episode in range(self.eps):
            state = env.reset()
            state = self.untuple(state)
            state = np.array(state).reshape((1,4))
            done=False
            i=0
            if not training:
                break
            while not done:
                i+=1
                action= self.act(state)
                next_state, reward, done, info, _ = env.step(action)
                if (done and i!=self.env._max_episode_steps-1) or state[0][0]>1:
                    reward = -100
                    done=True

                reward -= abs(state[0][0])
                reward -= abs(state[0][2])
                
                next_state=self.untuple(next_state)
                next_state= np.array(next_state).reshape((1,4))
                self.remember(state, action, reward, next_state, done)
                state = next_state

                if done:
                    print("episode: {}/{}, score: {}".format(episode, self.eps, i))

                    
                    if i>=1000:
                        training= False
                        # self.save("cartpole.h5")
                        break

                self.replay_memory()


    def test(self):
        env = gym.make("Cartpole-v1", render_mode="human")
        self.load("cartpole.h5")
        for episode in range(10):
            state = env.reset()
            state = self.untuple(state)
            state = np.array(state).reshape((1,4))
            done = False
            while not done:
                action = np.argmax(self.main_nn.predict(state, verbose=0))
                next_state, action, reward, done, info = env.step(action)
                state = np.array(self.untuple(next_state)).reshape((1,4))

# %%
cart_pole = agent1()
cart_pole.run()
# Out:
# episode: 0/1000, score: 16
# episode: 1/1000, score: 26
# episode: 2/1000, score: 27
# episode: 3/1000, score: 16
# episode: 4/1000, score: 24
# episode: 5/1000, score: 13
# episode: 6/1000, score: 16
# episode: 7/1000, score: 18
# episode: 8/1000, score: 11
# episode: 9/1000, score: 47
# episode: 10/1000, score: 12
# episode: 11/1000, score: 17
# episode: 12/1000, score: 22
# episode: 13/1000, score: 13
# episode: 14/1000, score: 13
# episode: 15/1000, score: 16
# episode: 16/1000, score: 11
# episode: 17/1000, score: 11
# episode: 18/1000, score: 13
# episode: 19/1000, score: 24
# episode: 20/1000, score: 22
# episode: 21/1000, score: 28
# episode: 22/1000, score: 30
# episode: 23/1000, score: 14
# episode: 24/1000, score: 36
# episode: 25/1000, score: 13
# episode: 26/1000, score: 31
# episode: 27/1000, score: 21
# episode: 28/1000, score: 15
# episode: 29/1000, score: 14
# episode: 30/1000, score: 48
# episode: 31/1000, score: 28
# episode: 32/1000, score: 12
# episode: 33/1000, score: 9
# episode: 34/1000, score: 26
# episode: 35/1000, score: 17
# episode: 36/1000, score: 14
# episode: 37/1000, score: 26
# episode: 38/1000, score: 46
# episode: 39/1000, score: 18
# episode: 40/1000, score: 19
# episode: 41/1000, score: 15
# episode: 42/1000, score: 27
# episode: 43/1000, score: 17
# episode: 44/1000, score: 15
# episode: 45/1000, score: 18
# episode: 46/1000, score: 10
# episode: 47/1000, score: 13
# episode: 48/1000, score: 11
# episode: 49/1000, score: 15
# episode: 50/1000, score: 12
# episode: 51/1000, score: 16
# episode: 52/1000, score: 16
# episode: 53/1000, score: 23
# episode: 54/1000, score: 17
# episode: 55/1000, score: 32
# episode: 56/1000, score: 30
# episode: 57/1000, score: 44
# episode: 58/1000, score: 52
# episode: 59/1000, score: 97
# episode: 60/1000, score: 19
# episode: 61/1000, score: 127
# episode: 62/1000, score: 201
# episode: 63/1000, score: 120
# episode: 64/1000, score: 138
# episode: 65/1000, score: 123
# episode: 66/1000, score: 130
# episode: 67/1000, score: 136
# episode: 68/1000, score: 97
# episode: 69/1000, score: 123
# episode: 70/1000, score: 142
# episode: 71/1000, score: 87
# episode: 72/1000, score: 142
# episode: 73/1000, score: 157
# episode: 74/1000, score: 147
# episode: 75/1000, score: 128
# episode: 76/1000, score: 143
# episode: 77/1000, score: 167
# episode: 78/1000, score: 156
# episode: 79/1000, score: 114
# episode: 80/1000, score: 166
# episode: 81/1000, score: 144
# episode: 82/1000, score: 130
# episode: 83/1000, score: 233
# episode: 84/1000, score: 160
# episode: 85/1000, score: 136
# episode: 86/1000, score: 239
# episode: 87/1000, score: 148
# episode: 88/1000, score: 181
# episode: 89/1000, score: 152
# episode: 90/1000, score: 123
# episode: 91/1000, score: 208
# episode: 92/1000, score: 152
# episode: 93/1000, score: 182
# episode: 94/1000, score: 135
# episode: 95/1000, score: 134
# episode: 96/1000, score: 113
# episode: 97/1000, score: 168
# episode: 98/1000, score: 128
# episode: 99/1000, score: 122
# episode: 100/1000, score: 161
# episode: 101/1000, score: 152
# episode: 102/1000, score: 184
# episode: 103/1000, score: 142
# episode: 104/1000, score: 128
# episode: 105/1000, score: 99
# episode: 106/1000, score: 159
# episode: 107/1000, score: 129
# episode: 108/1000, score: 140
# episode: 109/1000, score: 118
# episode: 110/1000, score: 78
# episode: 111/1000, score: 52
# episode: 112/1000, score: 32
# episode: 113/1000, score: 11
# episode: 114/1000, score: 9
# episode: 115/1000, score: 169
# episode: 116/1000, score: 178
# episode: 117/1000, score: 136
# episode: 118/1000, score: 114
# episode: 119/1000, score: 167
# episode: 120/1000, score: 153
# episode: 121/1000, score: 176
# episode: 122/1000, score: 108
# episode: 123/1000, score: 95
# episode: 124/1000, score: 119
# episode: 125/1000, score: 103
# episode: 126/1000, score: 125
# episode: 127/1000, score: 98
# episode: 128/1000, score: 194
# episode: 129/1000, score: 297
# episode: 130/1000, score: 263
# episode: 131/1000, score: 157
# episode: 132/1000, score: 232
# episode: 133/1000, score: 251
# episode: 134/1000, score: 204
# episode: 135/1000, score: 143
# episode: 136/1000, score: 141
# episode: 137/1000, score: 139
# episode: 138/1000, score: 149
# episode: 139/1000, score: 126
# episode: 140/1000, score: 107
# episode: 141/1000, score: 32
# episode: 142/1000, score: 127
# episode: 143/1000, score: 238
# episode: 144/1000, score: 135
# episode: 145/1000, score: 238
# episode: 146/1000, score: 301
# episode: 147/1000, score: 254
# episode: 148/1000, score: 179
# episode: 149/1000, score: 217
# episode: 150/1000, score: 193
# episode: 151/1000, score: 217
# episode: 152/1000, score: 236
# episode: 153/1000, score: 262
# episode: 154/1000, score: 286
# episode: 155/1000, score: 210
# episode: 156/1000, score: 305
# episode: 157/1000, score: 210
# episode: 158/1000, score: 219
# episode: 159/1000, score: 261
# episode: 160/1000, score: 174
# episode: 161/1000, score: 191
# episode: 162/1000, score: 221
# episode: 163/1000, score: 193
# episode: 164/1000, score: 180
# episode: 165/1000, score: 316
# episode: 166/1000, score: 256
# episode: 167/1000, score: 178
# episode: 168/1000, score: 162
# episode: 169/1000, score: 182
# episode: 170/1000, score: 227
# episode: 171/1000, score: 403
# episode: 172/1000, score: 404
# episode: 173/1000, score: 730
# episode: 174/1000, score: 204
# episode: 175/1000, score: 298
# episode: 176/1000, score: 363
# episode: 177/1000, score: 264
# episode: 178/1000, score: 248
# episode: 179/1000, score: 69
# episode: 180/1000, score: 154
# episode: 181/1000, score: 131
# episode: 182/1000, score: 188
# episode: 183/1000, score: 214
# episode: 184/1000, score: 620
# episode: 185/1000, score: 342
# episode: 186/1000, score: 810
# episode: 187/1000, score: 554
# episode: 188/1000, score: 648
# episode: 189/1000, score: 1071

# %%
cart_pole.save("final2.keras")
